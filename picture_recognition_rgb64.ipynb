# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import os
import collections
from time import perf_counter
from tensorflow.keras.models import load_model

# %%
model = load_model(r"D:/Research/Model/model_rgb_64")
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 62, 62, 32)        896
#
#  max_pooling2d (MaxPooling2D  (None, 31, 31, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 29, 29, 32)        9248
#
#  dropout (Dropout)           (None, 29, 29, 32)        0
#
#  flatten (Flatten)           (None, 26912)             0
#
#  dense (Dense)               (None, 128)               3444864
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense_1 (Dense)             (None, 5)                 645
#
# =================================================================
# Total params: 3,455,653
# Trainable params: 3,455,653
# Non-trainable params: 0
# _________________________________________________________________

# %%
# def number_of_elements(img):
#     H = []
#     S = []
#     V = []
#     for i in range(0,32):
#         for j in range(0,32):
#             H.append(img[i][j][0])
#             S.append(img[i][j][1])
#             V.append(img[i][j][2])
#     return H, S, V

# %%
start = perf_counter()
pic = r"D:/Research/Frame/testImage/g1_test.png"
img = cv2.imread(pic)
#plt.imshow(img)
img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
img = cv2.resize(img,(64,64))
# plt.imshow(img)
img = img.reshape(1,64,64,3)
test = model.predict(img)
np.set_printoptions(formatter={'float':'{:.4f}'.format})
print(test)
index = np.argmax(test)
print('Gesture:',index+1)
print(perf_counter() -start)
# Out:
# [[0.2218 0.1800 0.2201 0.1748 0.2033]]
# Gesture: 1
# 0.056902100000002065

# %%
pic = r"D:/Research/Frame/testImage/g2_test.png"
img = cv2.imread(pic)
#plt.imshow(img)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
img = cv2.resize(img, (64, 64))
plt.imshow(img)
img = img.reshape(1, 64, 64, 3)
test = model.predict(img)
np.set_printoptions(formatter={'float': '{:.4f}'.format})
print(test)
index = np.argmax(test)
print('Gesture:', index + 1)
# Out:
# [[0.2719 0.2410 0.4249 0.0086 0.0537]]
# Gesture: 3

# %%
pic = r"D:/Research/Frame/testImage/g3_test.png"
img = cv2.imread(pic)
#plt.imshow(img)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
img = cv2.resize(img, (64, 64))
plt.imshow(img)
img = img.reshape(1, 64, 64, 3)
test = model.predict(img)
np.set_printoptions(formatter={'float': '{:.4f}'.format})
print(test)
index = np.argmax(test)
print('Gesture:', index + 1)
# Out:
# [[0.6324 0.0883 0.2658 0.0018 0.0117]]
# Gesture: 1

# %%
pic = r"D:/Research/Frame/testImage/g4_test.png"
img = cv2.imread(pic)
#plt.imshow(img)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
img = cv2.resize(img, (64, 64))
plt.imshow(img)
img = img.reshape(1, 64, 64, 3)
test = model.predict(img)
np.set_printoptions(formatter={'float': '{:.4f}'.format})
print(test)
index = np.argmax(test)
print('Gesture:', index + 1)
# Out:
# [[0.1068 0.3599 0.5253 0.0012 0.0068]]
# Gesture: 3

# %%
pic = r"D:/Research/Frame/testImage/g5_test.png"
img = cv2.imread(pic)
#plt.imshow(img)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
img = cv2.resize(img, (64, 64))
plt.imshow(img)
img = img.reshape(1, 64, 64, 3)
test = model.predict(img)
np.set_printoptions(formatter={'float': '{:.4f}'.format})
print(test)
index = np.argmax(test)
print('Gesture:', index + 1)
# Out:
# [[0.2218 0.1800 0.2201 0.1748 0.2033]]
# Gesture: 1

# %%
# H,S,V = number_of_elements(img)
# h = collections.Counter(H)
# s = collections.Counter(S)
# v = collections.Counter(V)
# new_h = sorted(H)

# %%
# plt.hist(new_h,bins=180)

# %%
# plt.hist(S,bins=255)

# %%
# plt.hist(V,bins=255)

# %%
# lower = np.array([0,0,0],dtype='uint8')
# upper = np.array([90,10,255],dtype='uint8')
# skinRegionHSV = cv2.inRange(img, lower, upper)
# bin = cv2.blur(skinRegionHSV,(2,2))
# _,thresh = cv2.threshold(bin,0,255,cv2.THRESH_BINARY)
# plt.imshow(thresh)

# %%
# for i in range(0,32):
#     for j in range(0,32):
#         if thresh[i][j] == 0:
#             thresh[i][j] = 255
#         else:
#             thresh[i][j] = 0

# %%
# plt.imshow(thresh)

# %%
# #輪郭抽出
# contours,hierarchy = cv2.findContours(thresh,cv2.RETR_LIST,cv2.CHAIN_APPROX_SIMPLE)
# print(contours)
# contours = list(filter(lambda x: cv2.contourArea(x) > 50,contours))
# cv2.drawContours(thresh,contours,-1,color=(0,0,255),thickness=2)
# plt.imshow(thresh)

# %%
# for i in range(0,32):
#     for j in range(0,32):
#         if thresh[i][j] == 0:
#             thresh[i][j] = 255
#         else:
#             thresh[i][j] = 0

# %%
# thresh = thresh.reshape(1,64,64,1)

# %%
# test = model.predict(thresh)
# print(test)
