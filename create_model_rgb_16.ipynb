# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import os
import glob

from tensorflow.keras.utils import to_categorical
from tensorflow.keras.layers import Conv2D,MaxPooling2D,Dense,Dropout,Activation,Flatten
from tensorflow.keras.models import Sequential
from tensorflow.keras.preprocessing.image import array_to_img,img_to_array,load_img
from tensorflow.keras.losses import categorical_crossentropy
from sklearn.model_selection import train_test_split

# %%
def plot_loss_accuracy_graph(fit_record):
    plt.plot(fit_record.history['loss'],"-D",color="blue",label="train_loss",linewidth=2)
    plt.title('LOSS')
    plt.xlabel('EPOCHS')
    plt.ylabel('LOSS')
    plt.legend(loc="upper right")
    plt.show()
    
    plt.plot(fit_record.history['accuracy'],"-D",color="green",label="accuracy",linewidth=2)
    plt.title("ACCURACY")
    plt.xlabel('EPOCHS')
    plt.ylabel('ACCURACY')
    plt.legend(loc="upper right")
    plt.show()

# %%
#kaggleで入手したデータから1,2,3,5,7の5つを使って認識
X = [] #image data
Y = [] #category 0 to 4
input_path = r"D:/Research/Frame/leapGestRecog/"
img_size = (16,16)
# lower = np.array([0,0,0],dtype='uint8')
# upper = np.array([0,0,20],dtype='uint8')
# cate_num = 0
classes = ["0","1","2","3","4"]

# %%
g_name = '01_palm/'
cate_num = 0
cnt = 0
files = glob.glob(input_path+'00/'+g_name+'*')
for file in files:
    img = cv2.imread(file)
    # img = cv2.cvtColor(img,cv2.COLOR_BGR2HSV)
    img = cv2.resize(img,img_size)
    # skinRegionHSV = cv2.inRange(img,lower,upper)
    # img = cv2.blur(skinRegionHSV,(2,2))
    # _,img = cv2.threshold(img,0,255,cv2.THRESH_BINARY)
    img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
    cnt+=1
    X.append(img)
    Y.append(cate_num)
    plt.imshow(img)
print('{}:{}'.format(input_path+'00/'+g_name,cnt))

cnt = 0
files = glob.glob(input_path+'01/'+g_name+'*')
for file in files:
    img = cv2.imread(file)
    # img = cv2.cvtColor(img,cv2.COLOR_BGR2HSV)
    img = cv2.resize(img,img_size)
    # skinRegionHSV = cv2.inRange(img,lower,upper)
    # img = cv2.blur(skinRegionHSV,(2,2))
    # _,img = cv2.threshold(img,0,255,cv2.THRESH_BINARY)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    cnt+=1
    X.append(img)
    Y.append(cate_num)
print('{}:{}'.format(input_path+'01/'+g_name,cnt))

cnt = 0
files = glob.glob(input_path+'02/'+g_name+'*')
for file in files:
    img = cv2.imread(file)
    # img = cv2.cvtColor(img,cv2.COLOR_BGR2HSV)
    img = cv2.resize(img,img_size)
    # skinRegionHSV = cv2.inRange(img,lower,upper)
    # img = cv2.blur(skinRegionHSV,(2,2))
    # _,img = cv2.threshold(img,0,255,cv2.THRESH_BINARY)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    cnt+=1
    X.append(img)
    Y.append(cate_num)
print('{}:{}'.format(input_path+'02/'+g_name,cnt))

cnt = 0
files = glob.glob(input_path+'03/'+g_name+'*')
for file in files:
    img = cv2.imread(file)
    # img = cv2.cvtColor(img,cv2.COLOR_BGR2HSV)
    img = cv2.resize(img,img_size)
    # skinRegionHSV = cv2.inRange(img,lower,upper)
    # img = cv2.blur(skinRegionHSV,(2,2))
    # _,img = cv2.threshold(img,0,255,cv2.THRESH_BINARY)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    cnt+=1
    X.append(img)
    Y.append(cate_num)
print('{}:{}'.format(input_path+'03/'+g_name,cnt))

cnt = 0
files = glob.glob(input_path+'04/'+g_name+'*')
for file in files:
    img = cv2.imread(file)
    # img = cv2.cvtColor(img,cv2.COLOR_BGR2HSV)
    img = cv2.resize(img,img_size)
    # skinRegionHSV = cv2.inRange(img,lower,upper)
    # img = cv2.blur(skinRegionHSV,(2,2))
    # _,img = cv2.threshold(img,0,255,cv2.THRESH_BINARY)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    cnt+=1
    X.append(img)
    Y.append(cate_num)
print('{}:{}'.format(input_path+'04/'+g_name,cnt))

cnt = 0
files = glob.glob(input_path+'05/'+g_name+'*')
for file in files:
    img = cv2.imread(file)
    # img = cv2.cvtColor(img,cv2.COLOR_BGR2HSV)
    img = cv2.resize(img,img_size)
    # skinRegionHSV = cv2.inRange(img,lower,upper)
    # img = cv2.blur(skinRegionHSV,(2,2))
    # _,img = cv2.threshold(img,0,255,cv2.THRESH_BINARY)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    cnt+=1
    X.append(img)
    Y.append(cate_num)
print('{}:{}'.format(input_path+'05/'+g_name,cnt))

cnt = 0
files = glob.glob(input_path+'06/'+g_name+'*')
for file in files:
    img = cv2.imread(file)
    # img = cv2.cvtColor(img,cv2.COLOR_BGR2HSV)
    img = cv2.resize(img,img_size)
    # skinRegionHSV = cv2.inRange(img,lower,upper)
    # img = cv2.blur(skinRegionHSV,(2,2))
    # _,img = cv2.threshold(img,0,255,cv2.THRESH_BINARY)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    cnt+=1
    X.append(img)
    Y.append(cate_num)
print('{}:{}'.format(input_path+'06/'+g_name,cnt))

cnt = 0
files = glob.glob(input_path+'07/'+g_name+'*')
for file in files:
    img = cv2.imread(file)
    # img = cv2.cvtColor(img,cv2.COLOR_BGR2HSV)
    img = cv2.resize(img,img_size)
    # skinRegionHSV = cv2.inRange(img,lower,upper)
    # img = cv2.blur(skinRegionHSV,(2,2))
    # _,img = cv2.threshold(img,0,255,cv2.THRESH_BINARY)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    cnt+=1
    X.append(img)
    Y.append(cate_num)
print('{}:{}'.format(input_path+'07/'+g_name,cnt))

cnt = 0
files = glob.glob(input_path+'08/'+g_name+'*')
for file in files:
    img = cv2.imread(file)
    # img = cv2.cvtColor(img,cv2.COLOR_BGR2HSV)
    img = cv2.resize(img,img_size)
    # skinRegionHSV = cv2.inRange(img,lower,upper)
    # img = cv2.blur(skinRegionHSV,(2,2))
    # _,img = cv2.threshold(img,0,255,cv2.THRESH_BINARY)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    cnt+=1
    X.append(img)
    Y.append(cate_num)
print('{}:{}'.format(input_path+'08/'+g_name,cnt))

cnt = 0
files = glob.glob(input_path+'09/'+g_name+'*')
for file in files:
    img = cv2.imread(file)
    # img = cv2.cvtColor(img,cv2.COLOR_BGR2HSV)
    img = cv2.resize(img,img_size)
    # skinRegionHSV = cv2.inRange(img,lower,upper)
    # img = cv2.blur(skinRegionHSV,(2,2))
    # _,img = cv2.threshold(img,0,255,cv2.THRESH_BINARY)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    cnt+=1
    X.append(img)
    Y.append(cate_num)
print('{}:{}'.format(input_path+'09/'+g_name,cnt))
# Out:
# D:/Research/Frame/leapGestRecog/00/01_palm/:200
# D:/Research/Frame/leapGestRecog/01/01_palm/:200
# D:/Research/Frame/leapGestRecog/02/01_palm/:200
# D:/Research/Frame/leapGestRecog/03/01_palm/:200
# D:/Research/Frame/leapGestRecog/04/01_palm/:200
# D:/Research/Frame/leapGestRecog/05/01_palm/:200
# D:/Research/Frame/leapGestRecog/06/01_palm/:200
# D:/Research/Frame/leapGestRecog/07/01_palm/:200
# D:/Research/Frame/leapGestRecog/08/01_palm/:200
# D:/Research/Frame/leapGestRecog/09/01_palm/:200

# %%
g_name = '02_l/'
cnt = 0
cate_num = 1
files = glob.glob(input_path+'00/'+g_name+'*')
for file in files:
    img = cv2.imread(file)
    # img = cv2.cvtColor(img,cv2.COLOR_BGR2HSV)
    img = cv2.resize(img,img_size)
    # skinRegionHSV = cv2.inRange(img,lower,upper)
    # img = cv2.blur(skinRegionHSV,(2,2))
    # _,img = cv2.threshold(img,0,255,cv2.THRESH_BINARY)
    img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
    cnt+=1
    X.append(img)
    Y.append(cate_num)
    plt.imshow(img)
print('{}:{}'.format(input_path+'00/'+g_name,cnt))

cnt = 0
files = glob.glob(input_path+'01/'+g_name+'*')
for file in files:
    img = cv2.imread(file)
    # img = cv2.cvtColor(img,cv2.COLOR_BGR2HSV)
    img = cv2.resize(img,img_size)
    # skinRegionHSV = cv2.inRange(img,lower,upper)
    # img = cv2.blur(skinRegionHSV,(2,2))
    # _,img = cv2.threshold(img,0,255,cv2.THRESH_BINARY)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    cnt+=1
    X.append(img)
    Y.append(cate_num)
print('{}:{}'.format(input_path+'01/'+g_name,cnt))

cnt = 0
files = glob.glob(input_path+'02/'+g_name+'*')
for file in files:
    img = cv2.imread(file)
    # img = cv2.cvtColor(img,cv2.COLOR_BGR2HSV)
    img = cv2.resize(img,img_size)
    # skinRegionHSV = cv2.inRange(img,lower,upper)
    # img = cv2.blur(skinRegionHSV,(2,2))
    # _,img = cv2.threshold(img,0,255,cv2.THRESH_BINARY)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    cnt+=1
    X.append(img)
    Y.append(cate_num)
print('{}:{}'.format(input_path+'02/'+g_name,cnt))

cnt = 0
files = glob.glob(input_path+'03/'+g_name+'*')
for file in files:
    img = cv2.imread(file)
    # img = cv2.cvtColor(img,cv2.COLOR_BGR2HSV)
    img = cv2.resize(img,img_size)
    # skinRegionHSV = cv2.inRange(img,lower,upper)
    # img = cv2.blur(skinRegionHSV,(2,2))
    # _,img = cv2.threshold(img,0,255,cv2.THRESH_BINARY)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    cnt+=1
    X.append(img)
    Y.append(cate_num)
print('{}:{}'.format(input_path+'03/'+g_name,cnt))

cnt = 0
files = glob.glob(input_path+'04/'+g_name+'*')
for file in files:
    img = cv2.imread(file)
    # img = cv2.cvtColor(img,cv2.COLOR_BGR2HSV)
    img = cv2.resize(img,img_size)
    # skinRegionHSV = cv2.inRange(img,lower,upper)
    # img = cv2.blur(skinRegionHSV,(2,2))
    # _,img = cv2.threshold(img,0,255,cv2.THRESH_BINARY)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    cnt+=1
    X.append(img)
    Y.append(cate_num)
print('{}:{}'.format(input_path+'04/'+g_name,cnt))

cnt = 0
files = glob.glob(input_path+'05/'+g_name+'*')
for file in files:
    img = cv2.imread(file)
    # img = cv2.cvtColor(img,cv2.COLOR_BGR2HSV)
    img = cv2.resize(img,img_size)
    # skinRegionHSV = cv2.inRange(img,lower,upper)
    # img = cv2.blur(skinRegionHSV,(2,2))
    # _,img = cv2.threshold(img,0,255,cv2.THRESH_BINARY)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    cnt+=1
    X.append(img)
    Y.append(cate_num)
print('{}:{}'.format(input_path+'05/'+g_name,cnt))

cnt = 0
files = glob.glob(input_path+'06/'+g_name+'*')
for file in files:
    img = cv2.imread(file)
    # img = cv2.cvtColor(img,cv2.COLOR_BGR2HSV)
    img = cv2.resize(img,img_size)
    # skinRegionHSV = cv2.inRange(img,lower,upper)
    # img = cv2.blur(skinRegionHSV,(2,2))
    # _,img = cv2.threshold(img,0,255,cv2.THRESH_BINARY)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    cnt+=1
    X.append(img)
    Y.append(cate_num)
print('{}:{}'.format(input_path+'06/'+g_name,cnt))

cnt = 0
files = glob.glob(input_path+'07/'+g_name+'*')
for file in files:
    img = cv2.imread(file)
    # img = cv2.cvtColor(img,cv2.COLOR_BGR2HSV)
    img = cv2.resize(img,img_size)
    # skinRegionHSV = cv2.inRange(img,lower,upper)
    # img = cv2.blur(skinRegionHSV,(2,2))
    # _,img = cv2.threshold(img,0,255,cv2.THRESH_BINARY)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    cnt+=1
    X.append(img)
    Y.append(cate_num)
print('{}:{}'.format(input_path+'07/'+g_name,cnt))

cnt = 0
files = glob.glob(input_path+'08/'+g_name+'*')
for file in files:
    img = cv2.imread(file)
    # img = cv2.cvtColor(img,cv2.COLOR_BGR2HSV)
    img = cv2.resize(img,img_size)
    # skinRegionHSV = cv2.inRange(img,lower,upper)
    # img = cv2.blur(skinRegionHSV,(2,2))
    # _,img = cv2.threshold(img,0,255,cv2.THRESH_BINARY)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    cnt+=1
    X.append(img)
    Y.append(cate_num)
print('{}:{}'.format(input_path+'08/'+g_name,cnt))

cnt = 0
files = glob.glob(input_path+'09/'+g_name+'*')
for file in files:
    img = cv2.imread(file)
    # img = cv2.cvtColor(img,cv2.COLOR_BGR2HSV)
    img = cv2.resize(img,img_size)
    # skinRegionHSV = cv2.inRange(img,lower,upper)
    # img = cv2.blur(skinRegionHSV,(2,2))
    # _,img = cv2.threshold(img,0,255,cv2.THRESH_BINARY)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    cnt+=1
    X.append(img)
    Y.append(cate_num)
print('{}:{}'.format(input_path+'09/'+g_name,cnt))
# Out:
# D:/Research/Frame/leapGestRecog/00/02_l/:200
# D:/Research/Frame/leapGestRecog/01/02_l/:200
# D:/Research/Frame/leapGestRecog/02/02_l/:200
# D:/Research/Frame/leapGestRecog/03/02_l/:200
# D:/Research/Frame/leapGestRecog/04/02_l/:200
# D:/Research/Frame/leapGestRecog/05/02_l/:200
# D:/Research/Frame/leapGestRecog/06/02_l/:200
# D:/Research/Frame/leapGestRecog/07/02_l/:200
# D:/Research/Frame/leapGestRecog/08/02_l/:200
# D:/Research/Frame/leapGestRecog/09/02_l/:200

# %%
g_name = '03_fist/'
cnt = 0
cate_num = 2
files = glob.glob(input_path+'00/'+g_name+'*')
for file in files:
    img = cv2.imread(file)
    # img = cv2.cvtColor(img,cv2.COLOR_BGR2HSV)
    img = cv2.resize(img,img_size)
    # skinRegionHSV = cv2.inRange(img,lower,upper)
    # img = cv2.blur(skinRegionHSV,(2,2))
    # _,img = cv2.threshold(img,0,255,cv2.THRESH_BINARY)
    img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
    cnt+=1
    X.append(img)
    Y.append(cate_num)
    plt.imshow(img)
print('{}:{}'.format(input_path+'00/'+g_name,cnt))

cnt = 0
files = glob.glob(input_path+'01/'+g_name+'*')
for file in files:
    img = cv2.imread(file)
    # img = cv2.cvtColor(img,cv2.COLOR_BGR2HSV)
    img = cv2.resize(img,img_size)
    # skinRegionHSV = cv2.inRange(img,lower,upper)
    # img = cv2.blur(skinRegionHSV,(2,2))
    # _,img = cv2.threshold(img,0,255,cv2.THRESH_BINARY)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    cnt+=1
    X.append(img)
    Y.append(cate_num)
print('{}:{}'.format(input_path+'01/'+g_name,cnt))

cnt = 0
files = glob.glob(input_path+'02/'+g_name+'*')
for file in files:
    img = cv2.imread(file)
    # img = cv2.cvtColor(img,cv2.COLOR_BGR2HSV)
    img = cv2.resize(img,img_size)
    # skinRegionHSV = cv2.inRange(img,lower,upper)
    # img = cv2.blur(skinRegionHSV,(2,2))
    # _,img = cv2.threshold(img,0,255,cv2.THRESH_BINARY)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    cnt+=1
    X.append(img)
    Y.append(cate_num)
print('{}:{}'.format(input_path+'02/'+g_name,cnt))

cnt = 0
files = glob.glob(input_path+'03/'+g_name+'*')
for file in files:
    img = cv2.imread(file)
    # img = cv2.cvtColor(img,cv2.COLOR_BGR2HSV)
    img = cv2.resize(img,img_size)
    # skinRegionHSV = cv2.inRange(img,lower,upper)
    # img = cv2.blur(skinRegionHSV,(2,2))
    # _,img = cv2.threshold(img,0,255,cv2.THRESH_BINARY)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    cnt+=1
    X.append(img)
    Y.append(cate_num)
print('{}:{}'.format(input_path+'03/'+g_name,cnt))

cnt = 0
files = glob.glob(input_path+'04/'+g_name+'*')
for file in files:
    img = cv2.imread(file)
    # img = cv2.cvtColor(img,cv2.COLOR_BGR2HSV)
    img = cv2.resize(img,img_size)
    # skinRegionHSV = cv2.inRange(img,lower,upper)
    # img = cv2.blur(skinRegionHSV,(2,2))
    # _,img = cv2.threshold(img,0,255,cv2.THRESH_BINARY)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    cnt+=1
    X.append(img)
    Y.append(cate_num)
print('{}:{}'.format(input_path+'04/'+g_name,cnt))

cnt = 0
files = glob.glob(input_path+'05/'+g_name+'*')
for file in files:
    img = cv2.imread(file)
    # img = cv2.cvtColor(img,cv2.COLOR_BGR2HSV)
    img = cv2.resize(img,img_size)
    # skinRegionHSV = cv2.inRange(img,lower,upper)
    # img = cv2.blur(skinRegionHSV,(2,2))
    # _,img = cv2.threshold(img,0,255,cv2.THRESH_BINARY)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    cnt+=1
    X.append(img)
    Y.append(cate_num)
print('{}:{}'.format(input_path+'05/'+g_name,cnt))

cnt = 0
files = glob.glob(input_path+'06/'+g_name+'*')
for file in files:
    img = cv2.imread(file)
    # img = cv2.cvtColor(img,cv2.COLOR_BGR2HSV)
    img = cv2.resize(img,img_size)
    # skinRegionHSV = cv2.inRange(img,lower,upper)
    # img = cv2.blur(skinRegionHSV,(2,2))
    # _,img = cv2.threshold(img,0,255,cv2.THRESH_BINARY)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    cnt+=1
    X.append(img)
    Y.append(cate_num)
print('{}:{}'.format(input_path+'06/'+g_name,cnt))

cnt = 0
files = glob.glob(input_path+'07/'+g_name+'*')
for file in files:
    img = cv2.imread(file)
    # img = cv2.cvtColor(img,cv2.COLOR_BGR2HSV)
    img = cv2.resize(img,img_size)
    # skinRegionHSV = cv2.inRange(img,lower,upper)
    # img = cv2.blur(skinRegionHSV,(2,2))
    # _,img = cv2.threshold(img,0,255,cv2.THRESH_BINARY)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    cnt+=1
    X.append(img)
    Y.append(cate_num)
print('{}:{}'.format(input_path+'07/'+g_name,cnt))

cnt = 0
files = glob.glob(input_path+'08/'+g_name+'*')
for file in files:
    img = cv2.imread(file)
    # img = cv2.cvtColor(img,cv2.COLOR_BGR2HSV)
    img = cv2.resize(img,img_size)
    # skinRegionHSV = cv2.inRange(img,lower,upper)
    # img = cv2.blur(skinRegionHSV,(2,2))
    # _,img = cv2.threshold(img,0,255,cv2.THRESH_BINARY)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    cnt+=1
    X.append(img)
    Y.append(cate_num)
print('{}:{}'.format(input_path+'08/'+g_name,cnt))

cnt = 0
files = glob.glob(input_path+'09/'+g_name+'*')
for file in files:
    img = cv2.imread(file)
    # img = cv2.cvtColor(img,cv2.COLOR_BGR2HSV)
    img = cv2.resize(img,img_size)
    # skinRegionHSV = cv2.inRange(img,lower,upper)
    # img = cv2.blur(skinRegionHSV,(2,2))
    # _,img = cv2.threshold(img,0,255,cv2.THRESH_BINARY)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    cnt+=1
    X.append(img)
    Y.append(cate_num)
print('{}:{}'.format(input_path+'09/'+g_name,cnt))
# Out:
# D:/Research/Frame/leapGestRecog/00/03_fist/:200
# D:/Research/Frame/leapGestRecog/01/03_fist/:200
# D:/Research/Frame/leapGestRecog/02/03_fist/:200
# D:/Research/Frame/leapGestRecog/03/03_fist/:200
# D:/Research/Frame/leapGestRecog/04/03_fist/:200
# D:/Research/Frame/leapGestRecog/05/03_fist/:200
# D:/Research/Frame/leapGestRecog/06/03_fist/:200
# D:/Research/Frame/leapGestRecog/07/03_fist/:200
# D:/Research/Frame/leapGestRecog/08/03_fist/:200
# D:/Research/Frame/leapGestRecog/09/03_fist/:200

# %%
g_name = '05_thumb/'
cnt = 0
cate_num = 3
files = glob.glob(input_path+'00/'+g_name+'*')
for file in files:
    img = cv2.imread(file)
    # img = cv2.cvtColor(img,cv2.COLOR_BGR2HSV)
    img = cv2.resize(img,img_size)
    # skinRegionHSV = cv2.inRange(img,lower,upper)
    # img = cv2.blur(skinRegionHSV,(2,2))
    # _,img = cv2.threshold(img,0,255,cv2.THRESH_BINARY)
    img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
    cnt+=1
    X.append(img)
    Y.append(cate_num)
    plt.imshow(img)
print('{}:{}'.format(input_path+'00/'+g_name,cnt))

cnt = 0
files = glob.glob(input_path+'01/'+g_name+'*')
for file in files:
    img = cv2.imread(file)
    # img = cv2.cvtColor(img,cv2.COLOR_BGR2HSV)
    img = cv2.resize(img,img_size)
    # skinRegionHSV = cv2.inRange(img,lower,upper)
    # img = cv2.blur(skinRegionHSV,(2,2))
    # _,img = cv2.threshold(img,0,255,cv2.THRESH_BINARY)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    cnt+=1
    X.append(img)
    Y.append(cate_num)
print('{}:{}'.format(input_path+'01/'+g_name,cnt))

cnt = 0
files = glob.glob(input_path+'02/'+g_name+'*')
for file in files:
    img = cv2.imread(file)
    # img = cv2.cvtColor(img,cv2.COLOR_BGR2HSV)
    img = cv2.resize(img,img_size)
    # skinRegionHSV = cv2.inRange(img,lower,upper)
    # img = cv2.blur(skinRegionHSV,(2,2))
    # _,img = cv2.threshold(img,0,255,cv2.THRESH_BINARY)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    cnt+=1
    X.append(img)
    Y.append(cate_num)
print('{}:{}'.format(input_path+'02/'+g_name,cnt))

cnt = 0
files = glob.glob(input_path+'03/'+g_name+'*')
for file in files:
    img = cv2.imread(file)
    # img = cv2.cvtColor(img,cv2.COLOR_BGR2HSV)
    img = cv2.resize(img,img_size)
    # skinRegionHSV = cv2.inRange(img,lower,upper)
    # img = cv2.blur(skinRegionHSV,(2,2))
    # _,img = cv2.threshold(img,0,255,cv2.THRESH_BINARY)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    cnt+=1
    X.append(img)
    Y.append(cate_num)
print('{}:{}'.format(input_path+'03/'+g_name,cnt))

cnt = 0
files = glob.glob(input_path+'04/'+g_name+'*')
for file in files:
    img = cv2.imread(file)
    # img = cv2.cvtColor(img,cv2.COLOR_BGR2HSV)
    img = cv2.resize(img,img_size)
    # skinRegionHSV = cv2.inRange(img,lower,upper)
    # img = cv2.blur(skinRegionHSV,(2,2))
    # _,img = cv2.threshold(img,0,255,cv2.THRESH_BINARY)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    cnt+=1
    X.append(img)
    Y.append(cate_num)
print('{}:{}'.format(input_path+'04/'+g_name,cnt))

cnt = 0
files = glob.glob(input_path+'05/'+g_name+'*')
for file in files:
    img = cv2.imread(file)
    # img = cv2.cvtColor(img,cv2.COLOR_BGR2HSV)
    img = cv2.resize(img,img_size)
    # skinRegionHSV = cv2.inRange(img,lower,upper)
    # img = cv2.blur(skinRegionHSV,(2,2))
    # _,img = cv2.threshold(img,0,255,cv2.THRESH_BINARY)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    cnt+=1
    X.append(img)
    Y.append(cate_num)
print('{}:{}'.format(input_path+'05/'+g_name,cnt))

cnt = 0
files = glob.glob(input_path+'06/'+g_name+'*')
for file in files:
    img = cv2.imread(file)
    # img = cv2.cvtColor(img,cv2.COLOR_BGR2HSV)
    img = cv2.resize(img,img_size)
    # skinRegionHSV = cv2.inRange(img,lower,upper)
    # img = cv2.blur(skinRegionHSV,(2,2))
    # _,img = cv2.threshold(img,0,255,cv2.THRESH_BINARY)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    cnt+=1
    X.append(img)
    Y.append(cate_num)
print('{}:{}'.format(input_path+'06/'+g_name,cnt))

cnt = 0
files = glob.glob(input_path+'07/'+g_name+'*')
for file in files:
    img = cv2.imread(file)
    # img = cv2.cvtColor(img,cv2.COLOR_BGR2HSV)
    img = cv2.resize(img,img_size)
    # skinRegionHSV = cv2.inRange(img,lower,upper)
    # img = cv2.blur(skinRegionHSV,(2,2))
    # _,img = cv2.threshold(img,0,255,cv2.THRESH_BINARY)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    cnt+=1
    X.append(img)
    Y.append(cate_num)
print('{}:{}'.format(input_path+'07/'+g_name,cnt))

cnt = 0
files = glob.glob(input_path+'08/'+g_name+'*')
for file in files:
    img = cv2.imread(file)
    # img = cv2.cvtColor(img,cv2.COLOR_BGR2HSV)
    img = cv2.resize(img,img_size)
    # skinRegionHSV = cv2.inRange(img,lower,upper)
    # img = cv2.blur(skinRegionHSV,(2,2))
    # _,img = cv2.threshold(img,0,255,cv2.THRESH_BINARY)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    cnt+=1
    X.append(img)
    Y.append(cate_num)
print('{}:{}'.format(input_path+'08/'+g_name,cnt))

cnt = 0
files = glob.glob(input_path+'09/'+g_name+'*')
for file in files:
    img = cv2.imread(file)
    # img = cv2.cvtColor(img,cv2.COLOR_BGR2HSV)
    img = cv2.resize(img,img_size)
    # skinRegionHSV = cv2.inRange(img,lower,upper)
    # img = cv2.blur(skinRegionHSV,(2,2))
    # _,img = cv2.threshold(img,0,255,cv2.THRESH_BINARY)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    cnt+=1
    X.append(img)
    Y.append(cate_num)
print('{}:{}'.format(input_path+'09/'+g_name,cnt))
# Out:
# D:/Research/Frame/leapGestRecog/00/05_thumb/:200
# D:/Research/Frame/leapGestRecog/01/05_thumb/:200
# D:/Research/Frame/leapGestRecog/02/05_thumb/:200
# D:/Research/Frame/leapGestRecog/03/05_thumb/:200
# D:/Research/Frame/leapGestRecog/04/05_thumb/:200
# D:/Research/Frame/leapGestRecog/05/05_thumb/:200
# D:/Research/Frame/leapGestRecog/06/05_thumb/:200
# D:/Research/Frame/leapGestRecog/07/05_thumb/:200
# D:/Research/Frame/leapGestRecog/08/05_thumb/:200
# D:/Research/Frame/leapGestRecog/09/05_thumb/:200

# %%
g_name = '07_ok/'
cnt = 0
cate_num = 4
files = glob.glob(input_path+'00/'+g_name+'*')
for file in files:
    img = cv2.imread(file)
    # img = cv2.cvtColor(img,cv2.COLOR_BGR2HSV)
    img = cv2.resize(img,img_size)
    # skinRegionHSV = cv2.inRange(img,lower,upper)
    # img = cv2.blur(skinRegionHSV,(2,2))
    # _,img = cv2.threshold(img,0,255,cv2.THRESH_BINARY)
    img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
    cnt+=1
    X.append(img)
    Y.append(cate_num)
    plt.imshow(img)
print('{}:{}'.format(input_path+'00/'+g_name,cnt))

cnt = 0
files = glob.glob(input_path+'01/'+g_name+'*')
for file in files:
    img = cv2.imread(file)
    # img = cv2.cvtColor(img,cv2.COLOR_BGR2HSV)
    img = cv2.resize(img,img_size)
    # skinRegionHSV = cv2.inRange(img,lower,upper)
    # img = cv2.blur(skinRegionHSV,(2,2))
    # _,img = cv2.threshold(img,0,255,cv2.THRESH_BINARY)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    cnt+=1
    X.append(img)
    Y.append(cate_num)
print('{}:{}'.format(input_path+'01/'+g_name,cnt))

cnt = 0
files = glob.glob(input_path+'02/'+g_name+'*')
for file in files:
    img = cv2.imread(file)
    # img = cv2.cvtColor(img,cv2.COLOR_BGR2HSV)
    img = cv2.resize(img,img_size)
    # skinRegionHSV = cv2.inRange(img,lower,upper)
    # img = cv2.blur(skinRegionHSV,(2,2))
    # _,img = cv2.threshold(img,0,255,cv2.THRESH_BINARY)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    cnt+=1
    X.append(img)
    Y.append(cate_num)
print('{}:{}'.format(input_path+'02/'+g_name,cnt))

cnt = 0
files = glob.glob(input_path+'03/'+g_name+'*')
for file in files:
    img = cv2.imread(file)
    # img = cv2.cvtColor(img,cv2.COLOR_BGR2HSV)
    img = cv2.resize(img,img_size)
    # skinRegionHSV = cv2.inRange(img,lower,upper)
    # img = cv2.blur(skinRegionHSV,(2,2))
    # _,img = cv2.threshold(img,0,255,cv2.THRESH_BINARY)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    cnt+=1
    X.append(img)
    Y.append(cate_num)
print('{}:{}'.format(input_path+'03/'+g_name,cnt))

cnt = 0
files = glob.glob(input_path+'04/'+g_name+'*')
for file in files:
    img = cv2.imread(file)
    # img = cv2.cvtColor(img,cv2.COLOR_BGR2HSV)
    img = cv2.resize(img,img_size)
    # skinRegionHSV = cv2.inRange(img,lower,upper)
    # img = cv2.blur(skinRegionHSV,(2,2))
    # _,img = cv2.threshold(img,0,255,cv2.THRESH_BINARY)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    cnt+=1
    X.append(img)
    Y.append(cate_num)
print('{}:{}'.format(input_path+'04/'+g_name,cnt))

cnt = 0
files = glob.glob(input_path+'05/'+g_name+'*')
for file in files:
    img = cv2.imread(file)
    # img = cv2.cvtColor(img,cv2.COLOR_BGR2HSV)
    img = cv2.resize(img,img_size)
    # skinRegionHSV = cv2.inRange(img,lower,upper)
    # img = cv2.blur(skinRegionHSV,(2,2))
    # _,img = cv2.threshold(img,0,255,cv2.THRESH_BINARY)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    cnt+=1
    X.append(img)
    Y.append(cate_num)
print('{}:{}'.format(input_path+'05/'+g_name,cnt))

cnt = 0
files = glob.glob(input_path+'06/'+g_name+'*')
for file in files:
    img = cv2.imread(file)
    # img = cv2.cvtColor(img,cv2.COLOR_BGR2HSV)
    img = cv2.resize(img,img_size)
    # skinRegionHSV = cv2.inRange(img,lower,upper)
    # img = cv2.blur(skinRegionHSV,(2,2))
    # _,img = cv2.threshold(img,0,255,cv2.THRESH_BINARY)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    cnt+=1
    X.append(img)
    Y.append(cate_num)
print('{}:{}'.format(input_path+'06/'+g_name,cnt))

cnt = 0
files = glob.glob(input_path+'07/'+g_name+'*')
for file in files:
    img = cv2.imread(file)
    # img = cv2.cvtColor(img,cv2.COLOR_BGR2HSV)
    img = cv2.resize(img,img_size)
    # skinRegionHSV = cv2.inRange(img,lower,upper)
    # img = cv2.blur(skinRegionHSV,(2,2))
    # _,img = cv2.threshold(img,0,255,cv2.THRESH_BINARY)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    cnt+=1
    X.append(img)
    Y.append(cate_num)
print('{}:{}'.format(input_path+'07/'+g_name,cnt))

cnt = 0
files = glob.glob(input_path+'08/'+g_name+'*')
for file in files:
    img = cv2.imread(file)
    # img = cv2.cvtColor(img,cv2.COLOR_BGR2HSV)
    img = cv2.resize(img,img_size)
    # skinRegionHSV = cv2.inRange(img,lower,upper)
    # img = cv2.blur(skinRegionHSV,(2,2))
    # _,img = cv2.threshold(img,0,255,cv2.THRESH_BINARY)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    cnt+=1
    X.append(img)
    Y.append(cate_num)
print('{}:{}'.format(input_path+'08/'+g_name,cnt))

cnt = 0
files = glob.glob(input_path+'09/'+g_name+'*')
for file in files:
    img = cv2.imread(file)
    # img = cv2.cvtColor(img,cv2.COLOR_BGR2HSV)
    img = cv2.resize(img,img_size)
    # skinRegionHSV = cv2.inRange(img,lower,upper)
    # img = cv2.blur(skinRegionHSV,(2,2))
    # _,img = cv2.threshold(img,0,255,cv2.THRESH_BINARY)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    cnt+=1
    X.append(img)
    Y.append(cate_num)
print('{}:{}'.format(input_path+'09/'+g_name,cnt))
# Out:
# D:/Research/Frame/leapGestRecog/00/07_ok/:200
# D:/Research/Frame/leapGestRecog/01/07_ok/:200
# D:/Research/Frame/leapGestRecog/02/07_ok/:200
# D:/Research/Frame/leapGestRecog/03/07_ok/:200
# D:/Research/Frame/leapGestRecog/04/07_ok/:200
# D:/Research/Frame/leapGestRecog/05/07_ok/:200
# D:/Research/Frame/leapGestRecog/06/07_ok/:200
# D:/Research/Frame/leapGestRecog/07/07_ok/:200
# D:/Research/Frame/leapGestRecog/08/07_ok/:200
# D:/Research/Frame/leapGestRecog/09/07_ok/:200

# %%
X = np.asarray(X)
Y = np.asarray(Y)
print(X.shape)
X = X.astype('float16')
reshape_size = (-1,16,16,3)
# X = X.reshape(reshape_size)
print(X.shape)
# X = X / 255.0
Y = to_categorical(Y,5)
#学習用とテスト用に分割
x_train,x_test,y_train,y_test = train_test_split(X,Y,test_size=0.3,shuffle=True)
x_train = x_train.reshape(reshape_size)
print(x_train.shape,x_test.shape)
x_test = x_test.reshape(reshape_size)
# Out:
# (10000, 16, 16, 3)
# (10000, 16, 16, 3)
# (7000, 16, 16, 3) (3000, 16, 16, 3)

# %%
#CNNモデルの構築
model = Sequential()
model.add(Conv2D(32,(3,3),activation='relu',input_shape=(16,16,3)))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Conv2D(32,(3,3),activation='relu'))
model.add(Dropout(0.25))
model.add(Flatten())
model.add(Dense(128,activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(5,activation='softmax'))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 14, 14, 32)        896
#
#  max_pooling2d (MaxPooling2D  (None, 7, 7, 32)         0
#  )
#
#  conv2d_1 (Conv2D)           (None, 5, 5, 32)          9248
#
#  dropout (Dropout)           (None, 5, 5, 32)          0
#
#  flatten (Flatten)           (None, 800)               0
#
#  dense (Dense)               (None, 128)               102528
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense_1 (Dense)             (None, 5)                 645
#
# =================================================================
# Total params: 113,317
# Trainable params: 113,317
# Non-trainable params: 0
# _________________________________________________________________

# %%
#モデルのコンパイル
model.compile(
    optimizer='adam',
    loss=categorical_crossentropy,
    metrics=['accuracy'],
)

# %%
#学習
EPOCHS = 10
BATCH_SIZE = 16
print('反復学習回数:',EPOCHS)
fit_record = model.fit(
    x_train,
    y_train,
    batch_size=BATCH_SIZE,
    epochs = EPOCHS,
    verbose = 1,
)
plot_loss_accuracy_graph(fit_record)
# Out:
# 反復学習回数: 10
# Epoch 1/10
# 438/438 [==============================] - 7s 6ms/step - loss: 1.6142 - accuracy: 0.7511
# Epoch 2/10
# 438/438 [==============================] - 3s 6ms/step - loss: 0.1869 - accuracy: 0.9343
# Epoch 3/10
# 438/438 [==============================] - 3s 6ms/step - loss: 0.1119 - accuracy: 0.9621
# Epoch 4/10
# 438/438 [==============================] - 3s 6ms/step - loss: 0.0813 - accuracy: 0.9733
# Epoch 5/10
# 438/438 [==============================] - 3s 6ms/step - loss: 0.0731 - accuracy: 0.9737
# Epoch 6/10
# 438/438 [==============================] - 3s 6ms/step - loss: 0.0628 - accuracy: 0.9790
# Epoch 7/10
# 438/438 [==============================] - 3s 6ms/step - loss: 0.0783 - accuracy: 0.9761
# Epoch 8/10
# 438/438 [==============================] - 3s 6ms/step - loss: 0.0688 - accuracy: 0.9783
# Epoch 9/10
# 438/438 [==============================] - 3s 6ms/step - loss: 0.0491 - accuracy: 0.9859
# Epoch 10/10
# 438/438 [==============================] - 3s 6ms/step - loss: 0.0435 - accuracy: 0.9870

# %%
def plot_image(data_location,prediction_array,real_teacher_label,dataset):
    prediction_array,real_teacher_label,img = prediction_array[data_location],real_teacher_label[data_location],dataset[data_location]
    img = np.array(img,dtype='uint8')
    plt.grid(False)
    plt.xticks([])
    plt.yticks([])
    plt.imshow(img)
    
    predicted_label = np.argmax(prediction_array)
    if predicted_label == real_teacher_label:
        color = "green"
    else:
        color = "red"
    plt.xlabel("{} {:2.0f}% ({})".format(classes[predicted_label], 100*np.max(prediction_array),classes[predicted_label]),color=color)

# %%
def plot_teacher_labels_graph(data_location,prediction_array,real_teacher_label):
    prediction_array,real_teacher_label = prediction_array[data_location],real_teacher_label[data_location]
    plt.grid(False)
    plt.xticks([])
    plt.yticks([])
    
    thisplot = plt.bar(range(5),prediction_array,color="#666666")
    plt.xlim(0,1)
    predicted_label = np.argmax(prediction_array)
    thisplot[predicted_label].set_color('red')
    thisplot[real_teacher_label].set_color('green')

# %%
def convertOneHotVector2Integers(one_hot_vector):
    return [np.where(r==1)[0][0] for r in one_hot_vector]

# %%
prediction_array = model.predict(x_test)
test_data = x_test.reshape(x_test.shape[0],16,16,3)
data_location = 118
plt.figure(figsize=(6,3))
plt.subplot(1,2,1)
plot_image(data_location, prediction_array,convertOneHotVector2Integers(y_test),test_data)
plt.subplot(1,2,2)
plot_teacher_labels_graph(data_location, prediction_array,convertOneHotVector2Integers(y_test))
_ = plt.xticks(range(5),classes,rotation=45)

# %%
data_location = 140
plt.figure(figsize=(6, 3))
plt.subplot(1, 2, 1)
plot_image(data_location, prediction_array,
           convertOneHotVector2Integers(y_test), test_data)
plt.subplot(1, 2, 2)
plot_teacher_labels_graph(data_location, prediction_array,
                          convertOneHotVector2Integers(y_test))
_ = plt.xticks(range(5), classes, rotation=45)

# %%
data_location = 84
plt.figure(figsize=(6, 3))
plt.subplot(1, 2, 1)
plot_image(data_location, prediction_array,
           convertOneHotVector2Integers(y_test), test_data)
plt.subplot(1, 2, 2)
plot_teacher_labels_graph(data_location, prediction_array,
                          convertOneHotVector2Integers(y_test))
_ = plt.xticks(range(5), classes, rotation=45)

# %%
data_location = 121
plt.figure(figsize=(6, 3))
plt.subplot(1, 2, 1)
plot_image(data_location, prediction_array,
           convertOneHotVector2Integers(y_test), test_data)
plt.subplot(1, 2, 2)
plot_teacher_labels_graph(data_location, prediction_array,
                          convertOneHotVector2Integers(y_test))
_ = plt.xticks(range(5), classes, rotation=45)

# %%
data_location = 123
plt.figure(figsize=(6, 3))
plt.subplot(1, 2, 1)
plot_image(data_location, prediction_array,
           convertOneHotVector2Integers(y_test), test_data)
plt.subplot(1, 2, 2)
plot_teacher_labels_graph(data_location, prediction_array,
                          convertOneHotVector2Integers(y_test))
_ = plt.xticks(range(5), classes, rotation=45)

# %%
model.save(r'D:/Research/Model/model_rgb_16/')
# Out:
# INFO:tensorflow:Assets written to: D:/Research/Model/model_rgb_16/assets
